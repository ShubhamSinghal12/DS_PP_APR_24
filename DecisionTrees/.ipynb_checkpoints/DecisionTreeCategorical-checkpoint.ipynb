# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./mushrooms.csv")

# %%
data.head()
# Out:
#   type cap_shape cap_surface cap_color bruises odor gill_attachment  \
# 0    p         x           s         n       t    p               f
# 1    e         x           s         y       t    a               f
# 2    e         b           s         w       t    l               f
# 3    p         x           y         w       t    p               f
# 4    e         x           s         g       f    n               f
#
#   gill_spacing gill_size gill_color  ... stalk_surface_below_ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk_color_above_ring stalk_color_below_ring veil_type veil_color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring_number ring_type spore_print_color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
data.shape
# Out:
# (8124, 23)

# %%
X,y = data.drop(['type'],axis = 1),data['type'].values
feature_names = data.columns[1:]

# %%
feature_names
# Out:
# Index(['cap_shape', 'cap_surface', 'cap_color', 'bruises', 'odor',
#        'gill_attachment', 'gill_spacing', 'gill_size', 'gill_color',
#        'stalk_shape', 'stalk_root', 'stalk_surface_above_ring',
#        'stalk_surface_below_ring', 'stalk_color_above_ring',
#        'stalk_color_below_ring', 'veil_type', 'veil_color', 'ring_number',
#        'ring_type', 'spore_print_color', 'population', 'habitat'],
#       dtype='object')

# %%
def entropy(y):
    classes,counts = np.unique(y,return_counts=True)
    prob = counts/len(y)

    return -1*np.sum(prob*np.log2(prob))

# %%
entropy([1,0,1,0])
# Out:
# 1.0

# %%
l = np.array([1,0,1,0,1,1,1,2,2,2,0])
l == 1
# Out:
# array([ True, False,  True, False,  True,  True,  True, False, False,
#        False, False])

# %%
class DecisionTree:
    def __init__(self,max_depth = 5,min_split = 2):
        self.max_depth = max_depth
        self.min_split = min_split
        
    def fit(self,X,y):
        self.labels = np.unique(y)
        self.root = self.constructNode(X,y,0)
        return self.root
    
    def constructNode(self,X,y,cur_depth):
        if len(X) == 0 or X.shape[1] == 0 or cur_depth > self.max_depth:
            return None

        if len(X) >= self.min_split:
            parentEntropy = self.entropy(y)
            weightedChildrenEntropy = np.zeros((X.shape[1],))
    
            for feat in range(X.shape[1]):
                feat_values = X.iloc[:,feat].unique()
                for feat_value in feat_values:
                    weightedChildrenEntropy[feat] += (X.iloc[:,feat] == feat_value).mean()*self.entropy(y[X.iloc[:,feat] == feat_value])
    
            feat = np.argmax(parentEntropy - weightedChildrenEntropy)
            
            node = {'column':X.columns[feat], 
                    'children':{},
                    'isLeaf':False
                   }
                    
            feat_values = X.iloc[:,feat].unique()
            for feat_value in feat_values:
                X_split = X.drop([X.columns[feat]],axis=1)[X.iloc[:,feat] == feat_value]
                y_split = y[X.iloc[:,feat] == feat_value]
                child_node = self.constructNode(X_split,y_split,cur_depth+1)
                if child_node == None:
                    node['isLeaf'] = True
                    break
                node['children'][feat_value] = child_node

        else:
            node = {'column':None, 
                    'children':{},
                    'isLeaf':True
                   }

        if node['isLeaf']:
            node['Predictions'] = self.predictions(y)

        return node

    def predictions(self,y):
        prob = np.zeros(self.labels.shape,dtype=np.float32)
        for i,cls in enumerate(self.labels):
            prob[i] = (y==cls).mean()

        return prob
            

    def entropy(self,y):
        classes,counts = np.unique(y,return_counts=True)
        prob = counts/len(y)
    
        return -1*np.sum(prob*np.log2(prob))

# %%
dt = DecisionTree()
dt.fit(X,y)
# Out:
# {'column': 'odor',
#  'children': {'p': {'column': 'cap_shape',
#    'children': {'x': {'column': 'cap_surface',
#      'children': {'s': {'column': 'cap_color',
#        'children': {'n': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'w': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'y': {'column': 'cap_color',
#        'children': {'w': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'n': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False},
#     'f': {'column': 'cap_surface',
#      'children': {'s': {'column': 'cap_color',
#        'children': {'w': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'n': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'y': {'column': 'cap_color',
#        'children': {'n': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'w': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False}},
#    'isLeaf': False},
#   'a': {'column': 'cap_shape',
#    'children': {'x': {'column': 'cap_surface',
#      'children': {'s': {'column': 'cap_color',
#        'children': {'y': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'w': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'y': {'column': 'cap_color',
#        'children': {'y': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'w': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'n': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'f': {'column': 'cap_color',
#        'children': {'y': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'w': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False},
#     'b': {'column': 'cap_surface',
#      'children': {'s': {'column': 'cap_color',
#        'children': {'w': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'y': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'y': {'column': 'cap_color',
#        'children': {'w': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'y': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False},
#     'f': {'column': 'cap_surface',
#      'children': {'y': {'column': 'cap_color',
#        'children': {'y': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'n': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       's': {'column': 'cap_color',
#        'children': {'w': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'y': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'f': {'column': 'cap_color',
#        'children': {'w': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'y': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False}},
#    'isLeaf': False},
#   'l': {'column': 'cap_shape',
#    'children': {'b': {'column': 'cap_surface',
#      'children': {'s': {'column': 'cap_color',
#        'children': {'w': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'y': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'y': {'column': 'cap_color',
#        'children': {'w': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'y': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False},
#     'x': {'column': 'cap_surface',
#      'children': {'y': {'column': 'cap_color',
#        'children': {'y': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'w': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'n': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'f': {'column': 'cap_color',
#        'children': {'y': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'w': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       's': {'column': 'cap_color',
#        'children': {'w': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'y': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False},
#     'f': {'column': 'cap_surface',
#      'children': {'y': {'column': 'cap_color',
#        'children': {'y': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'n': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'f': {'column': 'cap_color',
#        'children': {'y': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'w': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       's': {'column': 'cap_color',
#        'children': {'y': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'w': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False}},
#    'isLeaf': False},
#   'n': {'column': 'spore_print_color',
#    'children': {'n': {'column': 'cap_shape',
#      'children': {'x': {'column': 'cap_surface',
#        'children': {'s': {'column': 'cap_color',
#          'children': {'g': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'w': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'f': {'column': 'cap_color',
#          'children': {'g': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'w': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'e': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'y': {'column': 'cap_color',
#          'children': {'g': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'e': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       's': {'column': 'cap_surface',
#        'children': {'f': {'column': 'cap_color',
#          'children': {'g': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'f': {'column': 'cap_surface',
#        'children': {'f': {'column': 'cap_color',
#          'children': {'w': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'g': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'e': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         's': {'column': 'cap_color',
#          'children': {'g': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'w': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'y': {'column': 'cap_color',
#          'children': {'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'e': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'g': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'b': {'column': 'cap_surface',
#        'children': {'s': {'column': 'cap_color',
#          'children': {'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'k': {'column': 'cap_surface',
#        'children': {'s': {'column': 'cap_color',
#          'children': {'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False},
#     'k': {'column': 'cap_shape',
#      'children': {'x': {'column': 'cap_surface',
#        'children': {'f': {'column': 'cap_color',
#          'children': {'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'g': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'w': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'e': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         's': {'column': 'cap_color',
#          'children': {'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'w': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'g': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'y': {'column': 'cap_color',
#          'children': {'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'g': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'e': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'f': {'column': 'cap_surface',
#        'children': {'f': {'column': 'cap_color',
#          'children': {'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'g': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'w': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'e': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         's': {'column': 'cap_color',
#          'children': {'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'g': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'w': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'y': {'column': 'cap_color',
#          'children': {'e': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'g': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       's': {'column': 'cap_surface',
#        'children': {'f': {'column': 'cap_color',
#          'children': {'g': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False},
#     'w': {'column': 'habitat',
#      'children': {'w': {'column': 'cap_shape',
#        'children': {'x': {'column': 'cap_surface',
#          'children': {'y': {'column': 'cap_color',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           's': {'column': 'cap_color',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'f': {'column': 'cap_surface',
#          'children': {'s': {'column': 'cap_color',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'y': {'column': 'cap_color',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'k': {'column': 'cap_surface',
#          'children': {'s': {'column': 'cap_color',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'y': {'column': 'cap_color',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'l': {'column': 'cap_color',
#        'children': {'c': {'column': 'cap_shape',
#          'children': {'f': {'column': 'cap_surface',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'k': {'column': 'cap_surface',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'x': {'column': 'cap_surface',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'n': {'column': 'cap_shape',
#          'children': {'k': {'column': 'cap_surface',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'x': {'column': 'cap_surface',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'f': {'column': 'cap_surface',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'w': {'column': 'cap_shape',
#          'children': {'b': {'column': 'cap_surface',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)},
#           'f': {'column': 'cap_surface',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)},
#           'c': {'column': 'cap_surface',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)},
#           'k': {'column': 'cap_surface',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'y': {'column': 'cap_shape',
#          'children': {'b': {'column': 'cap_surface',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)},
#           'k': {'column': 'cap_surface',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)},
#           'f': {'column': 'cap_surface',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)},
#           'c': {'column': 'cap_surface',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'd': {'column': 'gill_size',
#        'children': {'n': {'column': 'cap_shape',
#          'children': {'k': {'column': 'cap_surface',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)},
#           'f': {'column': 'cap_surface',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)},
#           'b': {'column': 'cap_surface',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)},
#           'x': {'column': 'cap_surface',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'b': {'column': 'cap_shape',
#          'children': {'b': {'column': 'cap_surface',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'x': {'column': 'cap_surface',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'k': {'column': 'cap_surface',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'f': {'column': 'cap_surface',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'g': {'column': 'cap_shape',
#        'children': {'x': {'column': 'cap_surface',
#          'children': {'f': {'column': 'cap_color',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           's': {'column': 'cap_color',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'b': {'column': 'cap_surface',
#          'children': {'f': {'column': 'cap_color',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           's': {'column': 'cap_color',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'k': {'column': 'cap_surface',
#          'children': {'f': {'column': 'cap_color',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           's': {'column': 'cap_color',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'p': {'column': 'cap_shape',
#        'children': {'x': {'column': 'cap_surface',
#          'children': {'s': {'column': 'cap_color',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'y': {'column': 'cap_color',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'f': {'column': 'cap_surface',
#          'children': {'y': {'column': 'cap_color',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           's': {'column': 'cap_color',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'b': {'column': 'cap_surface',
#          'children': {'s': {'column': None,
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'y': {'column': None,
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'k': {'column': 'cap_surface',
#          'children': {'y': {'column': None,
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           's': {'column': None,
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False},
#     'h': {'column': 'cap_shape',
#      'children': {'f': {'column': 'cap_surface',
#        'children': {'y': {'column': 'cap_color',
#          'children': {'u': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'w': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'r': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'x': {'column': 'cap_surface',
#        'children': {'y': {'column': 'cap_color',
#          'children': {'r': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'u': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'w': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False},
#     'r': {'column': 'cap_shape',
#      'children': {'b': {'column': 'cap_surface',
#        'children': {'s': {'column': 'cap_color',
#          'children': {'b': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)},
#           'w': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)},
#           'p': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'y': {'column': 'cap_color',
#          'children': {'w': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)},
#           'p': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)},
#           'b': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'f': {'column': 'cap_surface',
#        'children': {'s': {'column': 'cap_color',
#          'children': {'w': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)},
#           'p': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)},
#           'b': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'y': {'column': 'cap_color',
#          'children': {'p': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)},
#           'b': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)},
#           'w': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False},
#     'o': {'column': 'cap_shape',
#      'children': {'b': {'column': 'cap_surface',
#        'children': {'s': {'column': 'cap_color',
#          'children': {'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'x': {'column': 'cap_surface',
#        'children': {'s': {'column': 'cap_color',
#          'children': {'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'k': {'column': 'cap_surface',
#        'children': {'s': {'column': 'cap_color',
#          'children': {'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'f': {'column': 'cap_surface',
#        'children': {'s': {'column': 'cap_color',
#          'children': {'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False},
#     'y': {'column': 'cap_shape',
#      'children': {'x': {'column': 'cap_surface',
#        'children': {'s': {'column': 'cap_color',
#          'children': {'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'b': {'column': 'cap_surface',
#        'children': {'s': {'column': 'cap_color',
#          'children': {'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'f': {'column': 'cap_surface',
#        'children': {'s': {'column': 'cap_color',
#          'children': {'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'k': {'column': 'cap_surface',
#        'children': {'s': {'column': 'cap_color',
#          'children': {'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False},
#     'b': {'column': 'cap_shape',
#      'children': {'x': {'column': 'cap_surface',
#        'children': {'s': {'column': 'cap_color',
#          'children': {'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'k': {'column': 'cap_surface',
#        'children': {'s': {'column': 'cap_color',
#          'children': {'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'b': {'column': 'cap_surface',
#        'children': {'s': {'column': 'cap_color',
#          'children': {'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'f': {'column': 'cap_surface',
#        'children': {'s': {'column': 'cap_color',
#          'children': {'n': {'column': 'bruises',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False}},
#    'isLeaf': False},
#   'f': {'column': 'cap_shape',
#    'children': {'x': {'column': 'cap_surface',
#      'children': {'f': {'column': 'cap_color',
#        'children': {'g': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'y': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'y': {'column': 'cap_color',
#        'children': {'y': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'g': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'n': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'e': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       's': {'column': 'cap_color',
#        'children': {'g': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'b': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'w': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'n': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'e': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False},
#     'f': {'column': 'cap_surface',
#      'children': {'f': {'column': 'cap_color',
#        'children': {'g': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'y': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'y': {'column': 'cap_color',
#        'children': {'g': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'y': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'n': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'e': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       's': {'column': 'cap_color',
#        'children': {'w': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'b': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'g': {'column': 'bruises',
#          'children': {'t': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'e': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'n': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False},
#     'k': {'column': 'cap_surface',
#      'children': {'s': {'column': 'cap_color',
#        'children': {'n': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'e': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'y': {'column': 'cap_color',
#        'children': {'e': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'n': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False}},
#    'isLeaf': False},
#   'c': {'column': 'cap_shape',
#    'children': {'x': {'column': 'cap_surface',
#      'children': {'s': {'column': 'cap_color',
#        'children': {'p': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'w': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'g': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'f': {'column': 'cap_color',
#        'children': {'p': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'w': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'g': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False}},
#    'isLeaf': False},
#   'y': {'column': 'cap_shape',
#    'children': {'x': {'column': 'cap_surface',
#      'children': {'y': {'column': 'cap_color',
#        'children': {'e': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'n': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       's': {'column': 'cap_color',
#        'children': {'e': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'n': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False},
#     'k': {'column': 'cap_surface',
#      'children': {'y': {'column': 'cap_color',
#        'children': {'n': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'e': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       's': {'column': 'cap_color',
#        'children': {'n': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'e': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False},
#     'f': {'column': 'cap_surface',
#      'children': {'y': {'column': 'cap_color',
#        'children': {'e': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'n': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       's': {'column': 'cap_color',
#        'children': {'e': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'n': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False}},
#    'isLeaf': False},
#   's': {'column': 'cap_shape',
#    'children': {'x': {'column': 'cap_surface',
#      'children': {'y': {'column': 'cap_color',
#        'children': {'n': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'e': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       's': {'column': 'cap_color',
#        'children': {'e': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'n': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False},
#     'f': {'column': 'cap_surface',
#      'children': {'s': {'column': 'cap_color',
#        'children': {'e': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'n': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'y': {'column': 'cap_color',
#        'children': {'e': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'n': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False},
#     'k': {'column': 'cap_surface',
#      'children': {'s': {'column': 'cap_color',
#        'children': {'e': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'n': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'y': {'column': 'cap_color',
#        'children': {'n': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'e': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False}},
#    'isLeaf': False},
#   'm': {'column': 'cap_shape',
#    'children': {'x': {'column': 'cap_surface',
#      'children': {'y': {'column': 'cap_color',
#        'children': {'e': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'n': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'c': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False},
#     'k': {'column': 'cap_surface',
#      'children': {'y': {'column': 'cap_color',
#        'children': {'c': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'n': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'e': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False},
#     'f': {'column': 'cap_surface',
#      'children': {'y': {'column': 'cap_color',
#        'children': {'e': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'n': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'c': {'column': 'bruises',
#          'children': {'f': {'column': 'gill_attachment',
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False}},
#    'isLeaf': False}},
#  'isLeaf': False}
