# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv('./Titanic.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
cols_drop = ['PassengerId', 'Name', 'Ticket', 'Cabin']

# %%
data = data.drop(cols_drop, axis = 1)

# %%
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
lab_enc = LabelEncoder()
data['Sex'] = lab_enc.fit_transform(data['Sex'])
data['Embarked'] = lab_enc.fit_transform(data['Embarked'])
data.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    1  22.0      1      0   7.2500         2
# 1         1       1    0  38.0      1      0  71.2833         0
# 2         1       3    0  26.0      0      0   7.9250         2
# 3         1       1    0  35.0      1      0  53.1000         2
# 4         0       3    1  35.0      0      0   8.0500         2

# %%
data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      0
# dtype: int64

# %%
data = data.fillna(data['Age'].mean())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    int64
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  891 non-null    int64
# dtypes: float64(2), int64(6)
# memory usage: 55.8 KB

# %%
input_cols = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']
output_col = ['Survived']

X_data = data[input_cols]
Y_data = data['Survived']
X_data.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0       3    1  22.0      1      0   7.2500         2
# 1       1    0  38.0      1      0  71.2833         0
# 2       3    0  26.0      0      0   7.9250         2
# 3       1    0  35.0      1      0  53.1000         2
# 4       3    1  35.0      0      0   8.0500         2

# %%
print(X_data.shape, Y_data.shape)
# Out:
# (891, 7) (891,)

# %%
class DecisionTree:
    def __init__(self,max_depth = 10,min_split = 2):
        self.max_depth = max_depth
        self.min_split = min_split
        
    def fit(self,X,y):
        self.labels = np.unique(y)
        self.root = self.constructNode(X,y,0)
        # return self.root

    def traverse_predict(self,t,node):
        if node['isLeaf'] == True:
            return node['Predictions']
        else:
            if t[node['column']] < node['threshold']:
                return self.traverse_predict(t,node['children']['Left'])
            else:
                return self.traverse_predict(t,node['children']['Right'])

    def predict(self,t):
        predictions = []
        for i in range(len(t)):
            pred = self.traverse_predict(t.iloc[i],self.root)
            predictions.append(self.labels[np.argmax(pred)])
            
        return np.array(predictions)
    
    def constructNode(self,X,y,cur_depth):
        if len(X) == 0 or cur_depth > self.max_depth:
            return None

        if len(X) >= self.min_split:
            parentEntropy = self.entropy(y)
            weightedChildrenEntropy = np.zeros((X.shape[1],))
    
            for feat in range(X.shape[1]):
                th = X.iloc[:,feat].mean()
                weightedChildrenEntropy[feat] += (X.iloc[:,feat] < th).mean()*self.entropy(y[X.iloc[:,feat] < th])
                weightedChildrenEntropy[feat] += (X.iloc[:,feat] >= th).mean()*self.entropy(y[X.iloc[:,feat] >= th])
    
            feat = np.argmax(parentEntropy - weightedChildrenEntropy)
            th = X.iloc[:,feat].mean()
            node = {'column':X.columns[feat], 
                    'threshold':th,
                    'children':{},
                    'isLeaf':False
                   }
                    
            LX_split = X[X.iloc[:,feat] < th]
            Ly_split = y[X.iloc[:,feat] < th]
            Lchild_node = self.constructNode(LX_split,Ly_split,cur_depth+1)
            
            RX_split = X[X.iloc[:,feat] >= th]
            Ry_split = y[X.iloc[:,feat] >= th]
            Rchild_node = self.constructNode(RX_split,Ry_split,cur_depth+1)

            if Lchild_node == None or Rchild_node == None:
                node['isLeaf'] = True
            else:
                node['children']['Left'] = Lchild_node
                node['children']['Right'] = Rchild_node

        else:
            node = {'column':None, 
                    'children':{},
                    'isLeaf':True
                   }

        if node['isLeaf']:
            node['Predictions'] = self.predictions(y)

        return node

    def predictions(self,y):
        prob = np.zeros(self.labels.shape,dtype=np.float32)
        for i,cls in enumerate(self.labels):
            prob[i] = (y==cls).mean()

        return prob
            

    def entropy(self,y):
        classes,counts = np.unique(y,return_counts=True)
        prob = counts/len(y)
    
        return -1*np.sum(prob*np.log2(prob))

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
x_train,x_test,y_train,y_test = train_test_split(X_data,Y_data,train_size = 0.8)

# %%
dt = DecisionTree(max_depth=7)
# dt = DecisionTreeClassifier(max_depth=7)
# rf = RandomForestClassifier(1000,max_depth=7)
dt.fit(x_train,y_train)
dt.root
# Out:
# {'column': 'Sex',
#  'threshold': np.float64(0.6474719101123596),
#  'children': {'Left': {'column': 'Pclass',
#    'threshold': np.float64(2.135458167330677),
#    'children': {'Left': {'column': 'SibSp',
#      'threshold': np.float64(0.5539568345323741),
#      'children': {'Left': {'column': 'Embarked',
#        'threshold': np.float64(1.452054794520548),
#        'children': {'Left': {'column': 'Age',
#          'threshold': np.float64(34.34995989304812),
#          'children': {'Left': {'column': 'Pclass',
#            'threshold': np.float64(1.3333333333333333),
#            'children': {'Left': {'column': 'Pclass',
#              'threshold': np.float64(1.0),
#              'children': {},
#              'isLeaf': True,
#              'Predictions': array([0., 1.], dtype=float32)},
#             'Right': {'column': 'Pclass',
#              'threshold': np.float64(2.0),
#              'children': {},
#              'isLeaf': True,
#              'Predictions': array([0., 1.], dtype=float32)}},
#            'isLeaf': False},
#           'Right': {'column': 'Age',
#            'threshold': np.float64(45.2),
#            'children': {'Left': {'column': 'Pclass',
#              'threshold': np.float64(1.0),
#              'children': {},
#              'isLeaf': True,
#              'Predictions': array([0., 1.], dtype=float32)},
#             'Right': {'column': 'Age',
#              'threshold': np.float64(53.5),
#              'children': {'Left': {'column': 'Parch',
#                'threshold': np.float64(0.5),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.5, 0.5], dtype=float32)},
#               'Right': {'column': 'Pclass',
#                'threshold': np.float64(1.0),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0., 1.], dtype=float32)}},
#              'isLeaf': False}},
#            'isLeaf': False}},
#          'isLeaf': False},
#         'Right': {'column': 'Pclass',
#          'threshold': np.float64(1.5490196078431373),
#          'children': {'Left': {'column': 'Pclass',
#            'threshold': np.float64(1.0),
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)},
#           'Right': {'column': 'Pclass',
#            'threshold': np.float64(2.0),
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'Right': {'column': 'Embarked',
#        'threshold': np.float64(1.2878787878787878),
#        'children': {'Left': {'column': 'Pclass',
#          'threshold': np.float64(1.2083333333333333),
#          'children': {'Left': {'column': 'Pclass',
#            'threshold': np.float64(1.0),
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)},
#           'Right': {'column': 'Pclass',
#            'threshold': np.float64(2.0),
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False},
#         'Right': {'column': 'Age',
#          'threshold': np.float64(28.93088935574229),
#          'children': {'Left': {'column': 'Fare',
#            'threshold': np.float64(73.12222222222222),
#            'children': {'Left': {'column': 'Age',
#              'threshold': np.float64(17.285714285714285),
#              'children': {'Left': {'column': 'Pclass',
#                'threshold': np.float64(1.8),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0., 1.], dtype=float32)},
#               'Right': {'column': 'Age',
#                'threshold': np.float64(23.333333333333332),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.11111111, 0.8888889 ], dtype=float32)}},
#              'isLeaf': False},
#             'Right': {'column': 'SibSp',
#              'threshold': np.float64(2.0),
#              'children': {'Left': {'column': 'Pclass',
#                'threshold': np.float64(1.0),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([1., 0.], dtype=float32)},
#               'Right': {'column': 'Pclass',
#                'threshold': np.float64(1.0),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0., 1.], dtype=float32)}},
#              'isLeaf': False}},
#            'isLeaf': False},
#           'Right': {'column': 'Age',
#            'threshold': np.float64(37.46238970588235),
#            'children': {'Left': {'column': 'Pclass',
#              'threshold': np.float64(1.4666666666666666),
#              'children': {'Left': {'column': 'Pclass',
#                'threshold': np.float64(1.0),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0., 1.], dtype=float32)},
#               'Right': {'column': 'Pclass',
#                'threshold': np.float64(2.0),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0., 1.], dtype=float32)}},
#              'isLeaf': False},
#             'Right': {'column': 'Parch',
#              'threshold': np.float64(0.8888888888888888),
#              'children': {'Left': {'column': 'Pclass',
#                'threshold': np.float64(1.5),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.25, 0.75], dtype=float32)},
#               'Right': {'column': 'Pclass',
#                'threshold': np.float64(1.6),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0., 1.], dtype=float32)}},
#              'isLeaf': False}},
#            'isLeaf': False}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False},
#     'Right': {'column': 'Embarked',
#      'threshold': np.float64(1.3839285714285714),
#      'children': {'Left': {'column': 'Fare',
#        'threshold': np.float64(11.859357142857142),
#        'children': {'Left': {'column': 'Parch',
#          'threshold': np.float64(0.07142857142857142),
#          'children': {'Left': {'column': 'Embarked',
#            'threshold': np.float64(0.8518518518518519),
#            'children': {'Left': {'column': 'Pclass',
#              'threshold': np.float64(3.0),
#              'children': {},
#              'isLeaf': True,
#              'Predictions': array([0., 1.], dtype=float32)},
#             'Right': {'column': 'Fare',
#              'threshold': np.float64(7.75653043478261),
#              'children': {'Left': {'column': 'Fare',
#                'threshold': np.float64(7.673333333333333),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.33333334, 0.6666667 ], dtype=float32)},
#               'Right': {'column': 'Fare',
#                'threshold': np.float64(7.912525),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.125, 0.875], dtype=float32)}},
#              'isLeaf': False}},
#            'isLeaf': False},
#           'Right': {'column': None,
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False},
#         'Right': {'column': 'Fare',
#          'threshold': np.float64(17.23967619047619),
#          'children': {'Left': {'column': 'Fare',
#            'threshold': np.float64(14.837184615384615),
#            'children': {'Left': {'column': 'Fare',
#              'threshold': np.float64(14.307157142857145),
#              'children': {'Left': {'column': None,
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0., 1.], dtype=float32)},
#               'Right': {'column': 'Age',
#                'threshold': np.float64(25.149705882352936),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.8333333 , 0.16666667], dtype=float32)}},
#              'isLeaf': False},
#             'Right': {'column': 'Age',
#              'threshold': np.float64(25.18289215686274),
#              'children': {'Left': {'column': None,
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0., 1.], dtype=float32)},
#               'Right': {'column': 'Parch',
#                'threshold': np.float64(1.0),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.4, 0.6], dtype=float32)}},
#              'isLeaf': False}},
#            'isLeaf': False},
#           'Right': {'column': 'Pclass',
#            'threshold': np.float64(3.0),
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([0., 1.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'Right': {'column': 'Fare',
#        'threshold': np.float64(20.326125396825397),
#        'children': {'Left': {'column': 'Fare',
#          'threshold': np.float64(11.310744736842105),
#          'children': {'Left': {'column': 'Parch',
#            'threshold': np.float64(0.20833333333333334),
#            'children': {'Left': {'column': 'Age',
#              'threshold': np.float64(27.01991176470588),
#              'children': {'Left': {'column': 'Age',
#                'threshold': np.float64(22.46153846153846),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.3846154 , 0.61538464], dtype=float32)},
#               'Right': {'column': 'Fare',
#                'threshold': np.float64(8.5738),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.71428573, 0.2857143 ], dtype=float32)}},
#              'isLeaf': False},
#             'Right': {'column': 'Age',
#              'threshold': np.float64(18.75),
#              'children': {'Left': {'column': 'Pclass',
#                'threshold': np.float64(3.0),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0., 1.], dtype=float32)},
#               'Right': {'column': 'Age',
#                'threshold': np.float64(28.0),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.5, 0.5], dtype=float32)}},
#              'isLeaf': False}},
#            'isLeaf': False},
#           'Right': {'column': 'Age',
#            'threshold': np.float64(24.09987394957983),
#            'children': {'Left': {'column': 'Age',
#              'threshold': np.float64(10.6),
#              'children': {'Left': {'column': 'Pclass',
#                'threshold': np.float64(3.0),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0., 1.], dtype=float32)},
#               'Right': {'column': 'Age',
#                'threshold': np.float64(21.0),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.5, 0.5], dtype=float32)}},
#              'isLeaf': False},
#             'Right': {'column': 'Fare',
#              'threshold': np.float64(16.206944444444446),
#              'children': {'Left': {'column': 'Age',
#                'threshold': np.float64(29.566372549019604),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.16666667, 0.8333333 ], dtype=float32)},
#               'Right': {'column': 'Age',
#                'threshold': np.float64(35.666666666666664),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.6666667 , 0.33333334], dtype=float32)}},
#              'isLeaf': False}},
#            'isLeaf': False}},
#          'isLeaf': False},
#         'Right': {'column': 'Fare',
#          'threshold': np.float64(34.029503999999996),
#          'children': {'Left': {'column': 'SibSp',
#            'threshold': np.float64(2.2941176470588234),
#            'children': {'Left': {'column': 'SibSp',
#              'threshold': np.float64(0.5714285714285714),
#              'children': {'Left': {'column': 'Age',
#                'threshold': np.float64(14.333333333333334),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.6666667 , 0.33333334], dtype=float32)},
#               'Right': {'column': 'Pclass',
#                'threshold': np.float64(3.0),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.5, 0.5], dtype=float32)}},
#              'isLeaf': False},
#             'Right': {'column': 'SibSp',
#              'threshold': np.float64(3.5),
#              'children': {'Left': {'column': 'Pclass',
#                'threshold': np.float64(3.0),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([1., 0.], dtype=float32)},
#               'Right': {'column': 'Fare',
#                'threshold': np.float64(31.297499999999996),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.8, 0.2], dtype=float32)}},
#              'isLeaf': False}},
#            'isLeaf': False},
#           'Right': {'column': 'Pclass',
#            'threshold': np.float64(3.0),
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False}},
#    'isLeaf': False},
#   'Right': {'column': 'Fare',
#    'threshold': np.float64(26.148318004338392),
#    'children': {'Left': {'column': 'Parch',
#      'threshold': np.float64(0.09202453987730061),
#      'children': {'Left': {'column': 'Pclass',
#        'threshold': np.float64(2.7242524916943522),
#        'children': {'Left': {'column': 'Pclass',
#          'threshold': np.float64(1.8783783783783783),
#          'children': {'Left': {'column': 'Pclass',
#            'threshold': np.float64(1.0),
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)},
#           'Right': {'column': 'Age',
#            'threshold': np.float64(34.22913574660633),
#            'children': {'Left': {'column': 'Fare',
#              'threshold': np.float64(12.735019047619048),
#              'children': {'Left': {'column': 'Age',
#                'threshold': np.float64(26.471977124183006),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.9444444 , 0.05555556], dtype=float32)},
#               'Right': {'column': 'Age',
#                'threshold': np.float64(28.0165931372549),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.8333333 , 0.16666667], dtype=float32)}},
#              'isLeaf': False},
#             'Right': {'column': 'Age',
#              'threshold': np.float64(46.78260869565217),
#              'children': {'Left': {'column': 'Pclass',
#                'threshold': np.float64(2.0),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([1., 0.], dtype=float32)},
#               'Right': {'column': 'Age',
#                'threshold': np.float64(54.083333333333336),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.9166667 , 0.08333334], dtype=float32)}},
#              'isLeaf': False}},
#            'isLeaf': False}},
#          'isLeaf': False},
#         'Right': {'column': 'SibSp',
#          'threshold': np.float64(0.14096916299559473),
#          'children': {'Left': {'column': 'Fare',
#            'threshold': np.float64(8.24286567164179),
#            'children': {'Left': {'column': 'Fare',
#              'threshold': np.float64(7.600467857142857),
#              'children': {'Left': {'column': 'Age',
#                'threshold': np.float64(30.094089900110987),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.9056604 , 0.09433962], dtype=float32)},
#               'Right': {'column': 'Fare',
#                'threshold': np.float64(7.901260869565215),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.8695652 , 0.13043478], dtype=float32)}},
#              'isLeaf': False},
#             'Right': {'column': 'Age',
#              'threshold': np.float64(25.899839572192512),
#              'children': {'Left': {'column': 'Pclass',
#                'threshold': np.float64(3.0),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([1., 0.], dtype=float32)},
#               'Right': {'column': 'Fare',
#                'threshold': np.float64(12.107015789473683),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.84210527, 0.15789473], dtype=float32)}},
#              'isLeaf': False}},
#            'isLeaf': False},
#           'Right': {'column': 'Fare',
#            'threshold': np.float64(14.004653846153845),
#            'children': {'Left': {'column': 'Age',
#              'threshold': np.float64(24.06355614973262),
#              'children': {'Left': {'column': 'Age',
#                'threshold': np.float64(16.75),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.5, 0.5], dtype=float32)},
#               'Right': {'column': 'Age',
#                'threshold': np.float64(28.242731092436973),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.85714287, 0.14285715], dtype=float32)}},
#              'isLeaf': False},
#             'Right': {'column': 'SibSp',
#              'threshold': np.float64(1.2666666666666666),
#              'children': {'Left': {'column': 'Pclass',
#                'threshold': np.float64(3.0),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([1., 0.], dtype=float32)},
#               'Right': {'column': 'Age',
#                'threshold': np.float64(24.84955882352941),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.75, 0.25], dtype=float32)}},
#              'isLeaf': False}},
#            'isLeaf': False}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'Right': {'column': 'Age',
#        'threshold': np.float64(20.520694117647057),
#        'children': {'Left': {'column': 'Age',
#          'threshold': np.float64(9.70857142857143),
#          'children': {'Left': {'column': 'Age',
#            'threshold': np.float64(3.99),
#            'children': {'Left': {'column': 'Age',
#              'threshold': np.float64(0.98),
#              'children': {'Left': {'column': 'Pclass',
#                'threshold': np.float64(2.3333333333333335),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0., 1.], dtype=float32)},
#               'Right': {'column': None,
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([1., 0.], dtype=float32)}},
#              'isLeaf': False},
#             'Right': {'column': 'Pclass',
#              'threshold': np.float64(3.0),
#              'children': {},
#              'isLeaf': True,
#              'Predictions': array([0., 1.], dtype=float32)}},
#            'isLeaf': False},
#           'Right': {'column': 'Age',
#            'threshold': np.float64(17.333333333333332),
#            'children': {'Left': {'column': 'Pclass',
#              'threshold': np.float64(3.0),
#              'children': {},
#              'isLeaf': True,
#              'Predictions': array([1., 0.], dtype=float32)},
#             'Right': {'column': 'Age',
#              'threshold': np.float64(18.666666666666668),
#              'children': {'Left': {'column': 'Pclass',
#                'threshold': np.float64(3.0),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([1., 0.], dtype=float32)},
#               'Right': {'column': None,
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0., 1.], dtype=float32)}},
#              'isLeaf': False}},
#            'isLeaf': False}},
#          'isLeaf': False},
#         'Right': {'column': 'Embarked',
#          'threshold': np.float64(1.7272727272727273),
#          'children': {'Left': {'column': 'Age',
#            'threshold': np.float64(34.84955882352941),
#            'children': {'Left': {'column': None,
#              'children': {},
#              'isLeaf': True,
#              'Predictions': array([0., 1.], dtype=float32)},
#             'Right': {'column': None,
#              'children': {},
#              'isLeaf': True,
#              'Predictions': array([1., 0.], dtype=float32)}},
#            'isLeaf': False},
#           'Right': {'column': 'Pclass',
#            'threshold': np.float64(2.888888888888889),
#            'children': {'Left': {'column': None,
#              'children': {},
#              'isLeaf': True,
#              'Predictions': array([1., 0.], dtype=float32)},
#             'Right': {'column': 'Pclass',
#              'threshold': np.float64(3.0),
#              'children': {},
#              'isLeaf': True,
#              'Predictions': array([1., 0.], dtype=float32)}},
#            'isLeaf': False}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False},
#     'Right': {'column': 'Pclass',
#      'threshold': np.float64(1.5185185185185186),
#      'children': {'Left': {'column': 'Age',
#        'threshold': np.float64(39.99879795396419),
#        'children': {'Left': {'column': 'Age',
#          'threshold': np.float64(28.783457382953177),
#          'children': {'Left': {'column': 'Age',
#            'threshold': np.float64(22.333333333333332),
#            'children': {'Left': {'column': 'Parch',
#              'threshold': np.float64(1.2857142857142858),
#              'children': {'Left': {'column': 'Pclass',
#                'threshold': np.float64(1.0),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([1., 0.], dtype=float32)},
#               'Right': {'column': 'Fare',
#                'threshold': np.float64(143.93540000000002),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.25, 0.75], dtype=float32)}},
#              'isLeaf': False},
#             'Right': {'column': 'Age',
#              'threshold': np.float64(26.636363636363637),
#              'children': {'Left': {'column': 'Pclass',
#                'threshold': np.float64(1.0),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0., 1.], dtype=float32)},
#               'Right': {'column': 'Parch',
#                'threshold': np.float64(0.25),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.375, 0.625], dtype=float32)}},
#              'isLeaf': False}},
#            'isLeaf': False},
#           'Right': {'column': 'Age',
#            'threshold': np.float64(32.528690702087296),
#            'children': {'Left': {'column': 'Fare',
#              'threshold': np.float64(49.92267777777777),
#              'children': {'Left': {'column': 'Embarked',
#                'threshold': np.float64(1.0909090909090908),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.6363636 , 0.36363637], dtype=float32)},
#               'Right': {'column': 'Age',
#                'threshold': np.float64(30.15676470588235),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.85714287, 0.14285715], dtype=float32)}},
#              'isLeaf': False},
#             'Right': {'column': 'Age',
#              'threshold': np.float64(36.23076923076923),
#              'children': {'Left': {'column': 'Age',
#                'threshold': np.float64(35.5),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.25, 0.75], dtype=float32)},
#               'Right': {'column': 'SibSp',
#                'threshold': np.float64(0.6),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.6, 0.4], dtype=float32)}},
#              'isLeaf': False}},
#            'isLeaf': False}},
#          'isLeaf': False},
#         'Right': {'column': 'Parch',
#          'threshold': np.float64(0.27906976744186046),
#          'children': {'Left': {'column': 'Age',
#            'threshold': np.float64(51.614285714285714),
#            'children': {'Left': {'column': 'Age',
#              'threshold': np.float64(46.06818181818182),
#              'children': {'Left': {'column': 'Age',
#                'threshold': np.float64(43.31818181818182),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.6363636 , 0.36363637], dtype=float32)},
#               'Right': {'column': 'SibSp',
#                'threshold': np.float64(0.7272727272727273),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.36363637, 0.6363636 ], dtype=float32)}},
#              'isLeaf': False},
#             'Right': {'column': 'Age',
#              'threshold': np.float64(61.0),
#              'children': {'Left': {'column': 'Age',
#                'threshold': np.float64(56.0),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.71428573, 0.2857143 ], dtype=float32)},
#               'Right': {'column': 'Age',
#                'threshold': np.float64(66.83333333333333),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.8333333 , 0.16666667], dtype=float32)}},
#              'isLeaf': False}},
#            'isLeaf': False},
#           'Right': {'column': 'Pclass',
#            'threshold': np.float64(1.0),
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False},
#       'Right': {'column': 'SibSp',
#        'threshold': np.float64(2.744186046511628),
#        'children': {'Left': {'column': 'SibSp',
#          'threshold': np.float64(0.8260869565217391),
#          'children': {'Left': {'column': 'Pclass',
#            'threshold': np.float64(2.5),
#            'children': {'Left': {'column': 'Age',
#              'threshold': np.float64(17.0),
#              'children': {'Left': {'column': None,
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0., 1.], dtype=float32)},
#               'Right': {'column': 'Pclass',
#                'threshold': np.float64(2.0),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([1., 0.], dtype=float32)}},
#              'isLeaf': False},
#             'Right': {'column': 'Age',
#              'threshold': np.float64(29.5),
#              'children': {'Left': {'column': 'Age',
#                'threshold': np.float64(27.0),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.5, 0.5], dtype=float32)},
#               'Right': {'column': 'Pclass',
#                'threshold': np.float64(3.0),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0., 1.], dtype=float32)}},
#              'isLeaf': False}},
#            'isLeaf': False},
#           'Right': {'column': 'Age',
#            'threshold': np.float64(28.333333333333332),
#            'children': {'Left': {'column': 'Age',
#              'threshold': np.float64(16.285714285714285),
#              'children': {'Left': {'column': 'Pclass',
#                'threshold': np.float64(2.3333333333333335),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.33333334, 0.6666667 ], dtype=float32)},
#               'Right': {'column': 'Pclass',
#                'threshold': np.float64(2.0),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([1., 0.], dtype=float32)}},
#              'isLeaf': False},
#             'Right': {'column': 'Pclass',
#              'threshold': np.float64(2.25),
#              'children': {'Left': {'column': 'Pclass',
#                'threshold': np.float64(2.0),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([1., 0.], dtype=float32)},
#               'Right': {'column': 'Pclass',
#                'threshold': np.float64(3.0),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([1., 0.], dtype=float32)}},
#              'isLeaf': False}},
#            'isLeaf': False}},
#          'isLeaf': False},
#         'Right': {'column': 'SibSp',
#          'threshold': np.float64(4.95),
#          'children': {'Left': {'column': 'Parch',
#            'threshold': np.float64(1.3333333333333333),
#            'children': {'Left': {'column': 'Pclass',
#              'threshold': np.float64(3.0),
#              'children': {},
#              'isLeaf': True,
#              'Predictions': array([1., 0.], dtype=float32)},
#             'Right': {'column': 'Age',
#              'threshold': np.float64(5.0),
#              'children': {'Left': {'column': 'Age',
#                'threshold': np.float64(3.6666666666666665),
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([0.6666667 , 0.33333334], dtype=float32)},
#               'Right': {'column': None,
#                'children': {},
#                'isLeaf': True,
#                'Predictions': array([1., 0.], dtype=float32)}},
#              'isLeaf': False}},
#            'isLeaf': False},
#           'Right': {'column': 'Pclass',
#            'threshold': np.float64(3.0),
#            'children': {},
#            'isLeaf': True,
#            'Predictions': array([1., 0.], dtype=float32)}},
#          'isLeaf': False}},
#        'isLeaf': False}},
#      'isLeaf': False}},
#    'isLeaf': False}},
#  'isLeaf': False}

# %%
accuracy_score(y_train,rf.predict(x_train))
# Out:
# 0.8960674157303371

# %%
accuracy_score(y_test,rf.predict(x_test))
# Out:
# 0.8435754189944135
